# %%
import pandas as pd
import numpy as np

from google.cloud import bigquery as bq

# %matplotlib inline

# %%
gene = pd.read_table("./metadata/associated_genes_list.tsv", sep="\t")

print(gene.shape)
gene.head()
# Out:
# (3518, 5)
#   gene_symbol BRCA TN-BRCA nonTN-BRCA ERR-BRCA
# 0        A1CF  Yes      No         No      Yes
# 1        AACS  Yes      No         No       No
# 2       AARS2  Yes      No         No       No
# 3        AASS  Yes     Yes        Yes       No
# 4        AATF  Yes      No         No       No

# %%
subtypes = pd.read_table("./metadata/subtype_metadata.tsv", sep="\t")

print(subtypes.shape)
subtypes.head()
# Out:
# (1282, 12)
#    case_barcode    sample_barcode  sample_type     sample_type_name subtype  \
# 0  TCGA-A2-A04P  TCGA-A2-A04P-01A            1  Primary solid Tumor   Basal
# 1  TCGA-AR-A0TP  TCGA-AR-A0TP-01A            1  Primary solid Tumor   Basal
# 2  TCGA-GM-A2DF  TCGA-GM-A2DF-01A            1  Primary solid Tumor   Basal
# 3  TCGA-BH-A0C0  TCGA-BH-A0C0-01A            1  Primary solid Tumor    LumB
# 4  TCGA-D8-A141  TCGA-D8-A141-01A            1  Primary solid Tumor    LumA
#
#          ER        PR Her2_IHC  Her2_ISH      Her2 triple_negative subtype_sub
# 0  Negative  Negative      NaN  Negative  Negative             Yes    Basal-TN
# 1  Positive  Negative      NaN       NaN       NaN             NaN       Basal
# 2  Negative  Negative       1+  Negative  Negative             Yes    Basal-TN
# 3  Positive  Positive       2+  Positive       NaN             NaN        LumB
# 4  Positive  Positive       1+       NaN       NaN             NaN        LumA

# %%
# fill NaN value in subtype, triple_negative into Unknown
subtypes.fillna(value={'subtype': 'Unknown', 'triple_negative': 'Unknown', 'subtype_sub': 'Unknown'}, inplace=True)
subtypes.subtype_sub.value_counts()
# Out:
# LumA        581
# LumB        219
# Normal      143
# Basal       101
# Basal-TN     91
# Her2         82
# Unknown      65
# Name: subtype_sub, dtype: int64

# %%
hormone = pd.read_table("./metadata/hormone_metadata.tsv", sep="\t")

print(hormone.shape)
hormone.head()
# Out:
# (540, 15)
#    case_barcode    sample_barcode  sample_type     sample_type_name  \
# 0  TCGA-BH-A0C0  TCGA-BH-A0C0-01A            1  Primary solid Tumor
# 1  TCGA-BH-A0C0  TCGA-BH-A0C0-11A           11  Solid Tissue Normal
# 2  TCGA-D8-A141  TCGA-D8-A141-01A            1  Primary solid Tumor
# 3  TCGA-EW-A424  TCGA-EW-A424-01A            1  Primary solid Tumor
# 4  TCGA-AO-A12G  TCGA-AO-A12G-01A            1  Primary solid Tumor
#
#   initial_response recurrence_status  \
# 0          Unknown           Unknown
# 1          Unknown           Unknown
# 2          Unknown           Unknown
# 3          Unknown           Unknown
# 4          Unknown           Unknown
#
#                                       recurrence_log subtype        ER  \
# 0  Alive tumor free, last follow-up within risky ...    LumB  Positive
# 1  Alive tumor free, last follow-up within risky ...  Normal  Positive
# 2  Alive tumor free, last follow-up within risky ...    LumA  Positive
# 3  Alive tumor free, last follow-up within risky ...    LumA  Positive
# 4  Alive tumor free, last follow-up within risky ...    LumA  Positive
#
#          PR Her2_IHC  Her2_ISH Her2  triple_negative subtype_sub
# 0  Positive       2+  Positive  NaN              NaN        LumB
# 1  Positive       2+  Positive  NaN              NaN      Normal
# 2  Positive       1+       NaN  NaN              NaN        LumA
# 3  Positive      NaN       NaN  NaN              NaN        LumA
# 4  Positive       2+  Negative  NaN              NaN        LumA

# %% [markdown]
# -----------------------------------------------

# %%
sample_barcodes = ", ".join("'%s'" % w for w in subtypes.sample_barcode)
genes = ", ".join("'%s'" % w for w in gene.gene_symbol)

# %%
client = bq.Client()
rnaseq = 'isb-cgc.TCGA_hg19_data_v0.RNAseq_Gene_Expression_UNC_RSEM'

# some aliquots are duplicated => we take the average of those duplicates 
query="""\
SELECT 
    case_barcode, sample_barcode, aliquot_barcode, HGNC_gene_symbol, original_gene_symbol, 
    normalized_count,
    LOG(normalized_count + 1, 2) AS transformed_count
FROM
    `{}`
WHERE
    (sample_barcode IN ({})) AND 
    (HGNC_gene_symbol IN ({}) OR original_gene_symbol IN ({}))
""".format(rnaseq, sample_barcodes, genes, genes)

expression = client.query(query).to_dataframe()

print(expression.shape)

expression.head()
# Out:
# (4194180, 7)
#    case_barcode    sample_barcode               aliquot_barcode  \
# 0  TCGA-BH-A18P  TCGA-BH-A18P-11A  TCGA-BH-A18P-11A-43R-A12D-07
# 1  TCGA-BH-A0DG  TCGA-BH-A0DG-11A  TCGA-BH-A0DG-11A-43R-A12P-07
# 2  TCGA-BH-A0BM  TCGA-BH-A0BM-11A  TCGA-BH-A0BM-11A-12R-A089-07
# 3  TCGA-BH-A0DL  TCGA-BH-A0DL-11A  TCGA-BH-A0DL-11A-13R-A115-07
# 4  TCGA-BH-A0DV  TCGA-BH-A0DV-11A  TCGA-BH-A0DV-11A-22R-A12P-07
#
#   HGNC_gene_symbol original_gene_symbol  normalized_count  transformed_count
# 0           REPIN1               REPIN1         1616.0410          10.659141
# 1              JMY                  JMY         1500.2891          10.551986
# 2             BDNF                 BDNF           69.7229           6.144106
# 3            FOXD1                FOXD1           29.6156           4.936195
# 4            SBNO2                SBNO2         1280.1724          10.323249

# %%
expression['gene_symbol'] = expression[['HGNC_gene_symbol', 'original_gene_symbol']].apply(lambda x: 
                                                                                           x[1] if x[1] in gene.gene_symbol 
                                                                                           else x[0], axis=1)
expression.drop(['HGNC_gene_symbol', 'original_gene_symbol'], axis=1, inplace=True)

# %%
expression = expression.groupby(by=['case_barcode', 'sample_barcode', 'aliquot_barcode', 'gene_symbol'], 
                                as_index=False).mean()

print(expression.shape)
expression.head()
# Out:
# (4191750, 6)
#    case_barcode    sample_barcode               aliquot_barcode gene_symbol  \
# 0  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        A1CF
# 1  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AACS
# 2  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07       AARS2
# 3  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AASS
# 4  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AATF
#
#    normalized_count  transformed_count
# 0            0.0000           0.000000
# 1         1087.3986          10.087991
# 2          689.8967           9.432326
# 3           45.8396           5.549657
# 4         1518.9114          10.569772

# %%
print("Number of genes having expression data:")
expression.pivot(index='gene_symbol', columns='aliquot_barcode', values='transformed_count').shape[0]
# Out:
# Number of genes having expression data:
# 3450

# %%
expression.to_csv("./datasets/expression.IlluminaHiSeq.tsv", sep="\t", index=False)

# %% [markdown]
# ----------------------------------

# %%
expression = pd.read_table("./datasets/expression.IlluminaHiSeq.tsv", sep="\t")
print(expression.shape)
expression.head()
# Out:
# (4191750, 6)
#    case_barcode    sample_barcode               aliquot_barcode gene_symbol  \
# 0  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        A1CF
# 1  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AACS
# 2  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07       AARS2
# 3  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AASS
# 4  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AATF
#
#    normalized_count  transformed_count
# 0            0.0000           0.000000
# 1         1087.3986          10.087991
# 2          689.8967           9.432326
# 3           45.8396           5.549657
# 4         1518.9114          10.569772

# %% [markdown]
# # Subtype

# %%
subtype_genes = list(gene.loc[(gene['BRCA']=='Yes') | (gene['TN-BRCA']=='Yes') | (gene['nonTN-BRCA']=='Yes'), 
                              'gene_symbol'])
print(len(subtype_genes))

print(len(expression.loc[expression['gene_symbol'].isin(subtype_genes), 'gene_symbol'].unique()))

expression.loc[expression['gene_symbol'].isin(subtype_genes)].shape
# Out:
# 3470
# 3360
# (4082400, 6)

# %%
subtype_expression_bigtable = pd.merge(left = expression[expression['gene_symbol'].isin(subtype_genes)], 
                                       right = subtypes, how = 'inner', 
                                       on = ["sample_barcode", "case_barcode"])

print(subtype_expression_bigtable.shape)
subtype_expression_bigtable.head()
# Out:
# (4082400, 16)
#    case_barcode    sample_barcode               aliquot_barcode gene_symbol  \
# 0  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        A1CF
# 1  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AACS
# 2  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07       AARS2
# 3  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AASS
# 4  TCGA-3C-AAAU  TCGA-3C-AAAU-01A  TCGA-3C-AAAU-01A-11R-A41B-07        AATF
#
#    normalized_count  transformed_count  sample_type     sample_type_name  \
# 0            0.0000           0.000000            1  Primary solid Tumor
# 1         1087.3986          10.087991            1  Primary solid Tumor
# 2          689.8967           9.432326            1  Primary solid Tumor
# 3           45.8396           5.549657            1  Primary solid Tumor
# 4         1518.9114          10.569772            1  Primary solid Tumor
#
#   subtype        ER        PR Her2_IHC Her2_ISH Her2 triple_negative  \
# 0    LumA  Positive  Positive      NaN      NaN  NaN         Unknown
# 1    LumA  Positive  Positive      NaN      NaN  NaN         Unknown
# 2    LumA  Positive  Positive      NaN      NaN  NaN         Unknown
# 3    LumA  Positive  Positive      NaN      NaN  NaN         Unknown
# 4    LumA  Positive  Positive      NaN      NaN  NaN         Unknown
#
#   subtype_sub
# 0        LumA
# 1        LumA
# 2        LumA
# 3        LumA
# 4        LumA

# %%
subtype_expression_bigtable.drop_duplicates(subset=["sample_barcode", 
                                                    "gene_symbol"]).gene_symbol.value_counts().describe()
# Out:
# count    3360.0
# mean     1215.0
# std         0.0
# min      1215.0
# 25%      1215.0
# 50%      1215.0
# 75%      1215.0
# max      1215.0
# Name: gene_symbol, dtype: float64

# %% [markdown]
# ==> 1215 samples, each sample has expression data from 3360 genes associated with subtype-specific signatures

# %%
print("Sample types")
print(subtype_expression_bigtable.drop_duplicates(subset="sample_barcode").sample_type_name.value_counts())
print("\n")

print("BRCA subtypes")
print(subtype_expression_bigtable.drop_duplicates(subset="case_barcode").subtype_sub.value_counts())
# Out:
# Sample types
# Primary solid Tumor    1095
# Solid Tissue Normal     113
# Metastatic                7
# Name: sample_type_name, dtype: int64
#
#
# BRCA subtypes
# LumA        566
# LumB        217
# Basal       100
# Basal-TN     90
# Her2         82
# Normal       40
# Name: subtype_sub, dtype: int64

# %%
subtype_expression_bigtable.to_csv("./datasets/subtype_expression_bigtable.IlluminaHiSeq.tsv", sep="\t", index=False)

# %% [markdown]
# # Hormone

# %%
hormone_genes = list(gene.loc[gene['ERR-BRCA']=='Yes', 'gene_symbol'])
print(len(hormone_genes))

print(len(expression.loc[expression['gene_symbol'].isin(hormone_genes), 'gene_symbol'].unique()))

expression.loc[expression['gene_symbol'].isin(hormone_genes)].shape
# Out:
# 229
# 224
# (272160, 6)

# %%
hormone_expression_bigtable = pd.merge(left = expression[expression['gene_symbol'].isin(hormone_genes)], 
                                       right = hormone, how = 'inner', 
                                       on = ["sample_barcode", "case_barcode"])

print(hormone_expression_bigtable.shape)
hormone_expression_bigtable.head()
# Out:
# (115136, 19)
#    case_barcode    sample_barcode               aliquot_barcode gene_symbol  \
# 0  TCGA-5L-AAT0  TCGA-5L-AAT0-01A  TCGA-5L-AAT0-01A-12R-A41B-07        A1CF
# 1  TCGA-5L-AAT0  TCGA-5L-AAT0-01A  TCGA-5L-AAT0-01A-12R-A41B-07        AATK
# 2  TCGA-5L-AAT0  TCGA-5L-AAT0-01A  TCGA-5L-AAT0-01A-12R-A41B-07      ADRA2C
# 3  TCGA-5L-AAT0  TCGA-5L-AAT0-01A  TCGA-5L-AAT0-01A-12R-A41B-07      ANP32E
# 4  TCGA-5L-AAT0  TCGA-5L-AAT0-01A  TCGA-5L-AAT0-01A-12R-A41B-07    ARHGEF37
#
#    normalized_count  transformed_count  sample_type     sample_type_name  \
# 0            0.0000           0.000000            1  Primary solid Tumor
# 1           54.5535           5.795806            1  Primary solid Tumor
# 2           39.8885           5.353623            1  Primary solid Tumor
# 3          766.0947           9.583261            1  Primary solid Tumor
# 4         1644.2294          10.684073            1  Primary solid Tumor
#
#   initial_response recurrence_status recurrence_log subtype        ER  \
# 0          Unknown               NaN            NaN    LumA  Positive
# 1          Unknown               NaN            NaN    LumA  Positive
# 2          Unknown               NaN            NaN    LumA  Positive
# 3          Unknown               NaN            NaN    LumA  Positive
# 4          Unknown               NaN            NaN    LumA  Positive
#
#          PR Her2_IHC Her2_ISH Her2  triple_negative subtype_sub
# 0  Positive       1+      NaN  NaN              NaN        LumA
# 1  Positive       1+      NaN  NaN              NaN        LumA
# 2  Positive       1+      NaN  NaN              NaN        LumA
# 3  Positive       1+      NaN  NaN              NaN        LumA
# 4  Positive       1+      NaN  NaN              NaN        LumA

# %%
hormone_expression_bigtable.drop_duplicates(subset=["sample_barcode", 
                                                    "gene_symbol"]).gene_symbol.value_counts().describe()
# Out:
# count    224.0
# mean     514.0
# std        0.0
# min      514.0
# 25%      514.0
# 50%      514.0
# 75%      514.0
# max      514.0
# Name: gene_symbol, dtype: float64

# %% [markdown]
# ==> 514 samples, each sample has expression data for 224 genes associated with endocrine resistance signatures

# %%
print("Sample types")
print(hormone_expression_bigtable.drop_duplicates(subset="sample_barcode").sample_type_name.value_counts())
print("\n")

print("Cases - Initial responses")
print(hormone_expression_bigtable.drop_duplicates(subset="case_barcode").initial_response.value_counts())
print("\n")

print("Cases - Recurrence status")
print(hormone_expression_bigtable.drop_duplicates(subset="case_barcode").recurrence_status.value_counts())
print("\n")

print("Cases - Recurrence log")
print(hormone_expression_bigtable.drop_duplicates(subset="case_barcode").recurrence_log.value_counts())
print("\n")
# Out:
# Sample types
# Primary solid Tumor    480
# Solid Tissue Normal     33
# Metastatic               1
# Name: sample_type_name, dtype: int64
#
#
# Cases - Initial responses
# Unknown               431
# Complete response      40
# Progressive/Stable      9
# Name: initial_response, dtype: int64
#
#
# Cases - Recurrence status
# Unknown     423
# Occured      42
# Low risk      8
# Name: recurrence_status, dtype: int64
#
#
# Cases - Recurrence log
# Alive tumor free, last follow-up within risky period             376
# New tumor after/during treatment                                  30
# Drug start and end dates unknown                                  18
# Dead with tumor                                                   12
# Unknown neoplasm status                                           10
# Dead tumor free during risky period                                9
# Reported having tumor during follow-up but unknown recurrence      8
# Alive tumor free after risky period                                8
# Alive tumor free but unknown follow-up date                        2
# Name: recurrence_log, dtype: int64

# %%
hormone_expression_bigtable[hormone_expression_bigtable['sample_type']==6].drop_duplicates(subset=["initial_response", 
                                                                                                   "recurrence_status"])
# Out:
#        case_barcode    sample_barcode               aliquot_barcode  \
# 85120  TCGA-E2-A15E  TCGA-E2-A15E-06A  TCGA-E2-A15E-06A-11R-A12D-07
#
#       gene_symbol  normalized_count  transformed_count  sample_type  \
# 85120        A1CF            0.3766           0.461109            6
#
#       sample_type_name initial_response recurrence_status  \
# 85120       Metastatic          Unknown           Unknown
#
#                                           recurrence_log subtype        ER  \
# 85120  Alive tumor free, last follow-up within risky ...    LumA  Positive
#
#              PR Her2_IHC  Her2_ISH Her2  triple_negative subtype_sub
# 85120  Positive      NaN  Positive  NaN              NaN        LumA

# %%
hormone_tumors = hormone_expression_bigtable.loc[hormone_expression_bigtable['sample_type']==1].drop_duplicates(subset="case_barcode")
pd.crosstab(hormone_tumors['initial_response'], hormone_tumors['subtype_sub'], margins=True)
# Out:
# subtype_sub         Basal  Her2  LumA  LumB  Normal  All
# initial_response
# Complete response       2     1    30     6       1   40
# Progressive/Stable      0     1     6     1       1    9
# Unknown                 8    11   290   108      14  431
# All                    10    13   326   115      16  480

# %% [markdown]
# - Complete response: 2 Basal, 1 Normal-like
# - Progressive/Stable: 1 Normal-like

# %%
pd.crosstab(hormone_tumors['recurrence_status'], hormone_tumors['subtype_sub'], margins=True)
# Out:
# subtype_sub        Basal  Her2  LumA  LumB  Normal  All
# recurrence_status
# Low risk               0     0     8     0       0    8
# Occured                1     1    28    11       1   42
# Unknown                9    12   283   104      15  423
# All                   10    13   319   115      16  473

# %% [markdown]
# - Occured: 1 Basal, 1 Normal-like

# %%
hormone_expression_bigtable.to_csv("./datasets/hormone_expression_bigtable.IlluminaHiSeq.tsv", sep="\t", index=False)
